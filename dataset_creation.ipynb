# %%
import importlib


import src.circuit as crc
import src.dataset as ds

importlib.reload(ds)
importlib.reload(crc)
# Out:
# <module 'src.circuit' from 'c:\\Users\\jojow\\OneDrive\\Dokumente\\Life\\uni\\UPC\\Sem3\\I2R\\synthetic_quantum_circuit_generator\\src\\circuit.py'>

# %% [markdown]
# # Initial Dataset Creation
#
# For now, we create the dataset with only one specific circuit -> ensuring it works.
#
# *Attention*: Circuits are indexed by a multiindex: [name, num_qubits]. Therefore it's mandatory to name circuits uniquely AND always include "name" and "num_qubits" when using the src.dataset module like shown in this notebook to prevent data loss.

# %%
from typing import Dict, Any

dj_circuits = ds.instantiate_circuits(circuit_names=["dj"], n_vals=10)
def wrong_depth_to_dict(c: crc.Circuit) -> Dict[str, Any]:
    return {
        "name": c.name,
        "num_qubits": c.num_qubits,
        "num_gates": c.num_gates,
        "depth": c.depth + 1,  # intentionally wrong
    }

def size_feats_to_dict(c: crc.Circuit) -> Dict[str, Any]:
    return {
        "name": c.name,
        "num_qubits": c.num_qubits,
        "num_gates": c.num_gates,
        "num_1q_gates": c.num_1q_gates,
        "num_2q_gates": c.num_2q_gates,
        "pct_2q_gates": c.pct_2q_gates,
        "depth": c.depth,
    }
wrong_data = ds.collect_circuit_data(dj_circuits, dict_fn=wrong_depth_to_dict)
dataset = ds.create_append_or_update_dataset(wrong_data, save_csv=True)
print(dataset)

correct_data = ds.collect_circuit_data(dj_circuits, dict_fn=size_feats_to_dict)
dataset = ds.create_append_or_update_dataset(correct_data, save_csv=True)

print(dataset)
# Out:
# Created circuit dj with 2 qubits.
# Created circuit dj with 16 qubits.
# Created circuit dj with 30 qubits.
# Created circuit dj with 45 qubits.
# Created circuit dj with 59 qubits.
# Created circuit dj with 73 qubits.
# Created circuit dj with 87 qubits.
# Created circuit dj with 102 qubits.
# Created circuit dj with 116 qubits.
# Created circuit dj with 130 qubits.
# Processing circuit dj with 130 qubits.
# Processing circuit dj with 116 qubits.
# Processing circuit dj with 102 qubits.
# Processing circuit dj with 87 qubits.
# Processing circuit dj with 73 qubits.
# Processing circuit dj with 59 qubits.
# Processing circuit dj with 45 qubits.
# Processing circuit dj with 30 qubits.
# Processing circuit dj with 16 qubits.
# Processing circuit dj with 2 qubits.
#                  num_gates  depth
# name num_qubits
# dj   130              1037    138
#      116               925    124
#      102               807    110
#      87                692     94
#      73                584     80
#      59                474     66
#      45                362     53
#      30                241     38
#      16                125     23
#      2                  13     10
# Processing circuit dj with 130 qubits.
# Processing circuit dj with 116 qubits.
# Processing circuit dj with 102 qubits.
# Processing circuit dj with 87 qubits.
# Processing circuit dj with 73 qubits.
# Processing circuit dj with 59 qubits.
# Processing circuit dj with 45 qubits.
# Processing circuit dj with 30 qubits.
# Processing circuit dj with 16 qubits.
# Processing circuit dj with 2 qubits.
#                  num_gates  depth  num_1q_gates  num_2q_gates  pct_2q_gates
# name num_qubits
# dj   130              1037    137           908           129      0.124397
#      116               925    123           810           115      0.124324
#      102               807    109           706           101      0.125155
#      87                692     93           606            86      0.124277
#      73                584     79           512            72      0.123288
#      59                474     65           416            58      0.122363
#      45                362     52           318            44      0.121547
#      30                241     37           212            29      0.120332
#      16                125     22           110            15      0.120000
#      2                  13      9            12             1      0.076923

# %%
full_data = ds.collect_circuit_data(dj_circuits, dict_fn=crc.to_flattened_feature_dict)
dataset = ds.create_append_or_update_dataset(full_data, save_csv=True)

print(dataset)
# Out:
# Processing circuit dj with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
#                  num_gates  depth  size  num_1q_gates  num_2q_gates  \
# name num_qubits
# dj   130              1037    137  1037           908           129
#      116               925    123   925           810           115
#      102               807    109   807           706           101
#      87                692     93   692           606            86
#      73                584     79   584           512            72
#      59                474     65   474           416            58
#      45                362     52   362           318            44
#      30                241     37   241           212            29
#      16                125     22   125           110            15
#      2                  13      9    13            12             1
#
#                  pct_2q_gates   ig_aspl  ig_std_adj_mat  ig_diameter  \
# name num_qubits
# dj   130             0.124397  1.984615        0.123077            2
#      116             0.124324  1.982759        0.130170            2
#      102             0.125155  1.980392        0.138648            2
#      87              0.124277  1.977011        0.149867            2
#      73              0.123288  1.972603        0.163238            2
#      59              0.122363  1.966102        0.180967            2
#      45              0.121547  1.955556        0.206080            2
#      30              0.120332  1.933333        0.249444            2
#      16              0.120000  1.875000        0.330719            2
#      2               0.076923  1.000000        0.000000            1
#
#                  ig_max_betweenness  ...  ig_min_pagerank  ig_std_pagerank  \
# name num_qubits                      ...
# dj   130                        1.0  ...         0.004185         0.039834
#      116                        1.0  ...         0.004694         0.042109
#      102                        1.0  ...         0.005344         0.044819
#      87                         1.0  ...         0.006274         0.048408
#      73                         1.0  ...         0.007492         0.052662
#      59                         1.0  ...         0.009296         0.058287
#      45                         1.0  ...         0.012244         0.066189
#      30                         1.0  ...         0.018546         0.079633
#      16                         1.0  ...         0.035698         0.103804
#      2                          0.0  ...         0.500000         0.000000
#
#                  ig_normalized_hhi_pagerank  gdg_critical_path_length  \
# name num_qubits
# dj   130                           0.207871                       136
#      116                           0.207476                       122
#      102                           0.206919                       108
#      87                            0.206243                        92
#      73                            0.205262                        78
#      59                            0.203901                        64
#      45                            0.201627                        51
#      30                            0.196803                        36
#      16                            0.183898                        21
#      2                             0.000000                         8
#
#                  gdg_num_critical_paths  gdg_mean_path_length  \
# name num_qubits
# dj   130                              2             50.005168
#      116                              2             45.339130
#      102                              2             40.614433
#      87                               2             35.662921
#      73                               4             31.050370
#      59                               2             26.429621
#      45                               2             21.793037
#      30                               2             16.823276
#      16                               4             12.044444
#      2                                2              8.000000
#
#                  gdg_std_path_length  gdg_percentage_gates_in_critical_path  \
# name num_qubits
# dj   130                   30.798343                               0.132112
#      116                   27.505617                               0.132973
#      102                   24.159277                               0.135068
#      87                    20.610484                               0.134393
#      73                    17.301971                               0.135274
#      59                    14.007619                               0.137131
#      45                    10.715763                               0.143646
#      30                     7.275595                               0.153527
#      16                     3.848745                               0.176000
#      2                      0.000000                               0.692308
#
#                  density_score  idling_score
# name num_qubits
# dj   130              0.058224      0.934531
#      116              0.064829      0.927110
#      102              0.072577      0.918331
#      87               0.085646      0.903844
#      73               0.101442      0.886249
#      59               0.123873      0.861278
#      45               0.154720      0.826496
#      30               0.217148      0.756757
#      16               0.357576      0.602273
#      2                0.555556      0.222222
#
# [10 rows x 37 columns]

# %%
circuits = ds.instantiate_circuits(
    # takes kinda long (ae, shor)
    # grover: takes long for nqubit 50, more even: Error creating circuit grover with 100 qubits: loop of ufunc does not support argument 0 of type int which has no callable sqrt method
    # multiplier: Error creating circuit multiplier with x qubits: 'HighLevelSynthesis is unable to synthesize "measure"'
    # hrs_cumulative_multiplier, random_circuit, rg_qft_multiplier and qwalk: huge graphs that explode RAM
    except_names=[
        "ae",
        "shor",
        "multiplier",
        "grover",
        "hrs_cumulative_multiplier",
        "qwalk",
        "randomcircuit",
        "rg_qft_multiplier",
    ],
    n_vals=10,
    min_qubits=2,
    max_qubits=130,
    #level=BenchmarkLevel.NATIVEGATES,
)
data = ds.collect_circuit_data(circuits, dict_fn=crc.to_flattened_feature_dict, del_instances=True)
dataset = ds.create_append_or_update_dataset(data)
print(dataset)
# Out:
# Created circuit bmw_quark_cardinality with 2 qubits.
# Created circuit bmw_quark_cardinality with 16 qubits.
# Created circuit bmw_quark_cardinality with 30 qubits.
# Created circuit bmw_quark_cardinality with 45 qubits.
# Created circuit bmw_quark_cardinality with 59 qubits.
# Created circuit bmw_quark_cardinality with 73 qubits.
# Created circuit bmw_quark_cardinality with 87 qubits.
# Created circuit bmw_quark_cardinality with 102 qubits.
# Created circuit bmw_quark_cardinality with 116 qubits.
# Created circuit bmw_quark_cardinality with 130 qubits.
# Created circuit bmw_quark_copula with 2 qubits.
# Created circuit bmw_quark_copula with 16 qubits.
# Created circuit bmw_quark_copula with 30 qubits.
# Created circuit bmw_quark_copula with 44 qubits.
# Created circuit bmw_quark_copula with 58 qubits.
# Created circuit bmw_quark_copula with 74 qubits.
# Created circuit bmw_quark_copula with 88 qubits.
# Created circuit bmw_quark_copula with 102 qubits.
# Created circuit bmw_quark_copula with 116 qubits.
# Created circuit bmw_quark_copula with 130 qubits.
# Created circuit bv with 2 qubits.
# Created circuit bv with 16 qubits.
# Created circuit bv with 30 qubits.
# Created circuit bv with 45 qubits.
# Created circuit bv with 59 qubits.
# Created circuit bv with 73 qubits.
# Created circuit bv with 87 qubits.
# Created circuit bv with 102 qubits.
# Created circuit bv with 116 qubits.
# Created circuit bv with 130 qubits.
# Created circuit cdkm_ripple_carry_adder with 4 qubits.
# Created circuit cdkm_ripple_carry_adder with 18 qubits.
# Created circuit cdkm_ripple_carry_adder with 32 qubits.
# Created circuit cdkm_ripple_carry_adder with 46 qubits.
# Created circuit cdkm_ripple_carry_adder with 60 qubits.
# Created circuit cdkm_ripple_carry_adder with 74 qubits.
# Created circuit cdkm_ripple_carry_adder with 88 qubits.
# Created circuit cdkm_ripple_carry_adder with 102 qubits.
# Created circuit cdkm_ripple_carry_adder with 116 qubits.
# Created circuit cdkm_ripple_carry_adder with 130 qubits.
# Created circuit dj with 2 qubits.
# Created circuit dj with 16 qubits.
# Created circuit dj with 30 qubits.
# Created circuit dj with 45 qubits.
# Created circuit dj with 59 qubits.
# Created circuit dj with 73 qubits.
# Created circuit dj with 87 qubits.
# Created circuit dj with 102 qubits.
# Created circuit dj with 116 qubits.
# Created circuit dj with 130 qubits.
# Created circuit draper_qft_adder with 2 qubits.
# Created circuit draper_qft_adder with 16 qubits.
# Created circuit draper_qft_adder with 30 qubits.
# Created circuit draper_qft_adder with 44 qubits.
# Created circuit draper_qft_adder with 58 qubits.
# Created circuit draper_qft_adder with 74 qubits.
# Created circuit draper_qft_adder with 88 qubits.
# Created circuit draper_qft_adder with 102 qubits.
# Created circuit draper_qft_adder with 116 qubits.
# Created circuit draper_qft_adder with 130 qubits.
# Created circuit full_adder with 4 qubits.
# Created circuit full_adder with 18 qubits.
# Created circuit full_adder with 32 qubits.
# Created circuit full_adder with 46 qubits.
# Created circuit full_adder with 60 qubits.
# Created circuit full_adder with 74 qubits.
# Created circuit full_adder with 88 qubits.
# Created circuit full_adder with 102 qubits.
# Created circuit full_adder with 116 qubits.
# Created circuit full_adder with 130 qubits.
# Created circuit ghz with 2 qubits.
# Created circuit ghz with 16 qubits.
# Created circuit ghz with 30 qubits.
# Created circuit ghz with 45 qubits.
# Created circuit ghz with 59 qubits.
# Created circuit ghz with 73 qubits.
# Created circuit ghz with 87 qubits.
# Created circuit ghz with 102 qubits.
# Created circuit ghz with 116 qubits.
# Created circuit ghz with 130 qubits.
# Created circuit graphstate with 3 qubits.
# Created circuit graphstate with 17 qubits.
# Created circuit graphstate with 31 qubits.
# Created circuit graphstate with 45 qubits.
# Created circuit graphstate with 59 qubits.
# Created circuit graphstate with 74 qubits.
# Created circuit graphstate with 88 qubits.
# Created circuit graphstate with 102 qubits.
# Created circuit graphstate with 116 qubits.
# Created circuit graphstate with 130 qubits.
# Created circuit half_adder with 3 qubits.
# Created circuit half_adder with 17 qubits.
# Created circuit half_adder with 31 qubits.
# Created circuit half_adder with 45 qubits.
# Created circuit half_adder with 59 qubits.
# Created circuit half_adder with 73 qubits.
# Created circuit half_adder with 87 qubits.
# Created circuit half_adder with 101 qubits.
# Created circuit half_adder with 115 qubits.
# Created circuit half_adder with 129 qubits.
# Created circuit hhl with 3 qubits.
# Created circuit hhl with 17 qubits.
# Created circuit hhl with 31 qubits.
# Created circuit hhl with 45 qubits.
# Created circuit hhl with 59 qubits.
# Created circuit hhl with 74 qubits.
# Created circuit hhl with 88 qubits.
# Created circuit hhl with 102 qubits.
# Created circuit hhl with 116 qubits.
# Created circuit hhl with 130 qubits.
# Created circuit modular_adder with 2 qubits.
# Created circuit modular_adder with 16 qubits.
# Created circuit modular_adder with 30 qubits.
# Created circuit modular_adder with 44 qubits.
# Created circuit modular_adder with 58 qubits.
# Created circuit modular_adder with 74 qubits.
# Created circuit modular_adder with 88 qubits.
# Created circuit modular_adder with 102 qubits.
# Created circuit modular_adder with 116 qubits.
# Created circuit modular_adder with 130 qubits.
# Created circuit qaoa with 2 qubits.
# Created circuit qaoa with 16 qubits.
# Created circuit qaoa with 30 qubits.
# Created circuit qaoa with 45 qubits.
# Created circuit qaoa with 59 qubits.
# Created circuit qaoa with 73 qubits.
# Created circuit qaoa with 87 qubits.
# Created circuit qaoa with 102 qubits.
# Created circuit qaoa with 116 qubits.
# Created circuit qaoa with 130 qubits.
# Created circuit qft with 2 qubits.
# Created circuit qft with 16 qubits.
# Created circuit qft with 30 qubits.
# Created circuit qft with 45 qubits.
# Created circuit qft with 59 qubits.
# Created circuit qft with 73 qubits.
# Created circuit qft with 87 qubits.
# Created circuit qft with 102 qubits.
# Created circuit qft with 116 qubits.
# Created circuit qft with 130 qubits.
# Created circuit qftentangled with 2 qubits.
# Created circuit qftentangled with 16 qubits.
# Created circuit qftentangled with 30 qubits.
# Created circuit qftentangled with 45 qubits.
# Created circuit qftentangled with 59 qubits.
# Created circuit qftentangled with 73 qubits.
# Created circuit qftentangled with 87 qubits.
# Created circuit qftentangled with 102 qubits.
# Created circuit qftentangled with 116 qubits.
# Created circuit qftentangled with 130 qubits.
# Created circuit qnn with 2 qubits.
# Created circuit qnn with 16 qubits.
# Created circuit qnn with 30 qubits.
# Created circuit qnn with 45 qubits.
# Created circuit qnn with 59 qubits.
# Created circuit qnn with 73 qubits.
# Created circuit qnn with 87 qubits.
# Created circuit qnn with 102 qubits.
# Created circuit qnn with 116 qubits.
# Created circuit qnn with 130 qubits.
# Created circuit qpeexact with 2 qubits.
# Created circuit qpeexact with 16 qubits.
# Created circuit qpeexact with 30 qubits.
# Created circuit qpeexact with 45 qubits.
# Created circuit qpeexact with 59 qubits.
# Created circuit qpeexact with 73 qubits.
# Created circuit qpeexact with 87 qubits.
# Created circuit qpeexact with 102 qubits.
# Created circuit qpeexact with 116 qubits.
# Created circuit qpeexact with 130 qubits.
# Created circuit qpeinexact with 2 qubits.
# Created circuit qpeinexact with 16 qubits.
# Created circuit qpeinexact with 30 qubits.
# Created circuit qpeinexact with 45 qubits.
# Created circuit qpeinexact with 59 qubits.
# Created circuit qpeinexact with 73 qubits.
# Created circuit qpeinexact with 87 qubits.
# Created circuit qpeinexact with 102 qubits.
# Created circuit qpeinexact with 116 qubits.
# Created circuit qpeinexact with 130 qubits.
# Created circuit vbe_ripple_carry_adder with 4 qubits.
# Created circuit vbe_ripple_carry_adder with 19 qubits.
# Created circuit vbe_ripple_carry_adder with 31 qubits.
# Created circuit vbe_ripple_carry_adder with 46 qubits.
# Created circuit vbe_ripple_carry_adder with 61 qubits.
# Created circuit vbe_ripple_carry_adder with 73 qubits.
# Created circuit vbe_ripple_carry_adder with 88 qubits.
# Created circuit vbe_ripple_carry_adder with 103 qubits.
# Created circuit vbe_ripple_carry_adder with 115 qubits.
# Created circuit vbe_ripple_carry_adder with 130 qubits.
# Created circuit vqe_real_amp with 2 qubits.
# Created circuit vqe_real_amp with 16 qubits.
# Created circuit vqe_real_amp with 30 qubits.
# Created circuit vqe_real_amp with 45 qubits.
# Created circuit vqe_real_amp with 59 qubits.
# Created circuit vqe_real_amp with 73 qubits.
# Created circuit vqe_real_amp with 87 qubits.
# Created circuit vqe_real_amp with 102 qubits.
# Created circuit vqe_real_amp with 116 qubits.
# Created circuit vqe_real_amp with 130 qubits.
# Created circuit vqe_su2 with 2 qubits.
# Created circuit vqe_su2 with 16 qubits.
# Created circuit vqe_su2 with 30 qubits.
# Created circuit vqe_su2 with 45 qubits.
# Created circuit vqe_su2 with 59 qubits.
# Created circuit vqe_su2 with 73 qubits.
# Created circuit vqe_su2 with 87 qubits.
# Created circuit vqe_su2 with 102 qubits.
# Created circuit vqe_su2 with 116 qubits.
# Created circuit vqe_su2 with 130 qubits.
# Created circuit vqe_two_local with 2 qubits.
# Created circuit vqe_two_local with 16 qubits.
# Created circuit vqe_two_local with 30 qubits.
# Created circuit vqe_two_local with 45 qubits.
# Created circuit vqe_two_local with 59 qubits.
# Created circuit vqe_two_local with 73 qubits.
# Created circuit vqe_two_local with 87 qubits.
# Created circuit vqe_two_local with 102 qubits.
# Created circuit vqe_two_local with 116 qubits.
# Created circuit vqe_two_local with 130 qubits.
# Created circuit wstate with 2 qubits.
# Created circuit wstate with 16 qubits.
# Created circuit wstate with 30 qubits.
# Created circuit wstate with 45 qubits.
# Created circuit wstate with 59 qubits.
# Created circuit wstate with 73 qubits.
# Created circuit wstate with 87 qubits.
# Created circuit wstate with 102 qubits.
# Created circuit wstate with 116 qubits.
# Created circuit wstate with 130 qubits.
# Processing circuit bmw_quark_cardinality with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_cardinality with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_cardinality with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_cardinality with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_cardinality with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_cardinality with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_cardinality with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_cardinality with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_cardinality with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_cardinality with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_copula with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (65) and Rustworkx Stoer-Wagner min cut (65) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_copula with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (58) and Rustworkx Stoer-Wagner min cut (58) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_copula with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (51) and Rustworkx Stoer-Wagner min cut (51) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_copula with 88 qubits.
# Info: Agreement between NetworkX edge connectivity (44) and Rustworkx Stoer-Wagner min cut (44) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_copula with 74 qubits.
# Info: Agreement between NetworkX edge connectivity (37) and Rustworkx Stoer-Wagner min cut (37) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_copula with 58 qubits.
# Info: Agreement between NetworkX edge connectivity (29) and Rustworkx Stoer-Wagner min cut (29) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_copula with 44 qubits.
# Info: Agreement between NetworkX edge connectivity (22) and Rustworkx Stoer-Wagner min cut (22) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_copula with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (15) and Rustworkx Stoer-Wagner min cut (15) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_copula with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (8) and Rustworkx Stoer-Wagner min cut (8) BTW, its probably a good moment to remove nx now
# Processing circuit bmw_quark_copula with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit bv with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit bv with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit bv with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit bv with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit bv with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit bv with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit bv with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit bv with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit bv with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit bv with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit cdkm_ripple_carry_adder with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit cdkm_ripple_carry_adder with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit cdkm_ripple_carry_adder with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit cdkm_ripple_carry_adder with 88 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit cdkm_ripple_carry_adder with 74 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit cdkm_ripple_carry_adder with 60 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit cdkm_ripple_carry_adder with 46 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit cdkm_ripple_carry_adder with 32 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit cdkm_ripple_carry_adder with 18 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit cdkm_ripple_carry_adder with 4 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit dj with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit draper_qft_adder with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit draper_qft_adder with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit draper_qft_adder with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit draper_qft_adder with 88 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit draper_qft_adder with 74 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit draper_qft_adder with 58 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit draper_qft_adder with 44 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit draper_qft_adder with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit draper_qft_adder with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit draper_qft_adder with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit full_adder with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit full_adder with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit full_adder with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit full_adder with 88 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit full_adder with 74 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit full_adder with 60 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit full_adder with 46 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit full_adder with 32 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit full_adder with 18 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit full_adder with 4 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit ghz with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit ghz with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit ghz with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit ghz with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit ghz with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit ghz with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit ghz with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit ghz with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit ghz with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit ghz with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit graphstate with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit graphstate with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit graphstate with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit graphstate with 88 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit graphstate with 74 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit graphstate with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit graphstate with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit graphstate with 31 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit graphstate with 17 qubits.
# Info: Agreement between NetworkX edge connectivity (0) and Rustworkx Stoer-Wagner min cut (0) BTW, its probably a good moment to remove nx now
# Processing circuit graphstate with 3 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit half_adder with 129 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit half_adder with 115 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit half_adder with 101 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit half_adder with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit half_adder with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit half_adder with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit half_adder with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit half_adder with 31 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit half_adder with 17 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit half_adder with 3 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit hhl with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (128) and Rustworkx Stoer-Wagner min cut (128) BTW, its probably a good moment to remove nx now
# Processing circuit hhl with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (114) and Rustworkx Stoer-Wagner min cut (114) BTW, its probably a good moment to remove nx now
# Processing circuit hhl with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (100) and Rustworkx Stoer-Wagner min cut (100) BTW, its probably a good moment to remove nx now
# Processing circuit hhl with 88 qubits.
# Info: Agreement between NetworkX edge connectivity (86) and Rustworkx Stoer-Wagner min cut (86) BTW, its probably a good moment to remove nx now
# Processing circuit hhl with 74 qubits.
# Info: Agreement between NetworkX edge connectivity (72) and Rustworkx Stoer-Wagner min cut (72) BTW, its probably a good moment to remove nx now
# Processing circuit hhl with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (57) and Rustworkx Stoer-Wagner min cut (57) BTW, its probably a good moment to remove nx now
# Processing circuit hhl with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (43) and Rustworkx Stoer-Wagner min cut (43) BTW, its probably a good moment to remove nx now
# Processing circuit hhl with 31 qubits.
# Info: Agreement between NetworkX edge connectivity (29) and Rustworkx Stoer-Wagner min cut (29) BTW, its probably a good moment to remove nx now
# Processing circuit hhl with 17 qubits.
# Info: Agreement between NetworkX edge connectivity (15) and Rustworkx Stoer-Wagner min cut (15) BTW, its probably a good moment to remove nx now
# Processing circuit hhl with 3 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit modular_adder with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit modular_adder with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit modular_adder with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit modular_adder with 88 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit modular_adder with 74 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit modular_adder with 58 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit modular_adder with 44 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit modular_adder with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit modular_adder with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit modular_adder with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qaoa with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (44) and Rustworkx Stoer-Wagner min cut (44) BTW, its probably a good moment to remove nx now
# Processing circuit qaoa with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (40) and Rustworkx Stoer-Wagner min cut (40) BTW, its probably a good moment to remove nx now
# Processing circuit qaoa with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (37) and Rustworkx Stoer-Wagner min cut (37) BTW, its probably a good moment to remove nx now
# Processing circuit qaoa with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (28) and Rustworkx Stoer-Wagner min cut (28) BTW, its probably a good moment to remove nx now
# Processing circuit qaoa with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (26) and Rustworkx Stoer-Wagner min cut (26) BTW, its probably a good moment to remove nx now
# Processing circuit qaoa with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (22) and Rustworkx Stoer-Wagner min cut (22) BTW, its probably a good moment to remove nx now
# Processing circuit qaoa with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (15) and Rustworkx Stoer-Wagner min cut (15) BTW, its probably a good moment to remove nx now
# Processing circuit qaoa with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (9) and Rustworkx Stoer-Wagner min cut (9) BTW, its probably a good moment to remove nx now
# Processing circuit qaoa with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (4) and Rustworkx Stoer-Wagner min cut (4) BTW, its probably a good moment to remove nx now
# Processing circuit qaoa with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qft with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (129) and Rustworkx Stoer-Wagner min cut (129) BTW, its probably a good moment to remove nx now
# Processing circuit qft with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (115) and Rustworkx Stoer-Wagner min cut (115) BTW, its probably a good moment to remove nx now
# Processing circuit qft with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (101) and Rustworkx Stoer-Wagner min cut (101) BTW, its probably a good moment to remove nx now
# Processing circuit qft with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (86) and Rustworkx Stoer-Wagner min cut (86) BTW, its probably a good moment to remove nx now
# Processing circuit qft with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (72) and Rustworkx Stoer-Wagner min cut (72) BTW, its probably a good moment to remove nx now
# Processing circuit qft with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (58) and Rustworkx Stoer-Wagner min cut (58) BTW, its probably a good moment to remove nx now
# Processing circuit qft with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (44) and Rustworkx Stoer-Wagner min cut (44) BTW, its probably a good moment to remove nx now
# Processing circuit qft with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (29) and Rustworkx Stoer-Wagner min cut (29) BTW, its probably a good moment to remove nx now
# Processing circuit qft with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (15) and Rustworkx Stoer-Wagner min cut (15) BTW, its probably a good moment to remove nx now
# Processing circuit qft with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qftentangled with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (129) and Rustworkx Stoer-Wagner min cut (129) BTW, its probably a good moment to remove nx now
# Processing circuit qftentangled with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (115) and Rustworkx Stoer-Wagner min cut (115) BTW, its probably a good moment to remove nx now
# Processing circuit qftentangled with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (101) and Rustworkx Stoer-Wagner min cut (101) BTW, its probably a good moment to remove nx now
# Processing circuit qftentangled with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (86) and Rustworkx Stoer-Wagner min cut (86) BTW, its probably a good moment to remove nx now
# Processing circuit qftentangled with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (72) and Rustworkx Stoer-Wagner min cut (72) BTW, its probably a good moment to remove nx now
# Processing circuit qftentangled with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (58) and Rustworkx Stoer-Wagner min cut (58) BTW, its probably a good moment to remove nx now
# Processing circuit qftentangled with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (44) and Rustworkx Stoer-Wagner min cut (44) BTW, its probably a good moment to remove nx now
# Processing circuit qftentangled with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (29) and Rustworkx Stoer-Wagner min cut (29) BTW, its probably a good moment to remove nx now
# Processing circuit qftentangled with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (15) and Rustworkx Stoer-Wagner min cut (15) BTW, its probably a good moment to remove nx now
# Processing circuit qftentangled with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qnn with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qnn with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qnn with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qnn with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qnn with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qnn with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qnn with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qnn with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qnn with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qnn with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qpeexact with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (129) and Rustworkx Stoer-Wagner min cut (129) BTW, its probably a good moment to remove nx now
# Processing circuit qpeexact with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (115) and Rustworkx Stoer-Wagner min cut (115) BTW, its probably a good moment to remove nx now
# Processing circuit qpeexact with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (101) and Rustworkx Stoer-Wagner min cut (101) BTW, its probably a good moment to remove nx now
# Processing circuit qpeexact with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (86) and Rustworkx Stoer-Wagner min cut (86) BTW, its probably a good moment to remove nx now
# Processing circuit qpeexact with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (72) and Rustworkx Stoer-Wagner min cut (72) BTW, its probably a good moment to remove nx now
# Processing circuit qpeexact with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (58) and Rustworkx Stoer-Wagner min cut (58) BTW, its probably a good moment to remove nx now
# Processing circuit qpeexact with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (44) and Rustworkx Stoer-Wagner min cut (44) BTW, its probably a good moment to remove nx now
# Processing circuit qpeexact with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (28) and Rustworkx Stoer-Wagner min cut (28) BTW, its probably a good moment to remove nx now
# Processing circuit qpeexact with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (15) and Rustworkx Stoer-Wagner min cut (15) BTW, its probably a good moment to remove nx now
# Processing circuit qpeexact with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit qpeinexact with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (129) and Rustworkx Stoer-Wagner min cut (129) BTW, its probably a good moment to remove nx now
# Processing circuit qpeinexact with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (115) and Rustworkx Stoer-Wagner min cut (115) BTW, its probably a good moment to remove nx now
# Processing circuit qpeinexact with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (101) and Rustworkx Stoer-Wagner min cut (101) BTW, its probably a good moment to remove nx now
# Processing circuit qpeinexact with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (86) and Rustworkx Stoer-Wagner min cut (86) BTW, its probably a good moment to remove nx now
# Processing circuit qpeinexact with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (72) and Rustworkx Stoer-Wagner min cut (72) BTW, its probably a good moment to remove nx now
# Processing circuit qpeinexact with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (58) and Rustworkx Stoer-Wagner min cut (58) BTW, its probably a good moment to remove nx now
# Processing circuit qpeinexact with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (44) and Rustworkx Stoer-Wagner min cut (44) BTW, its probably a good moment to remove nx now
# Processing circuit qpeinexact with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (29) and Rustworkx Stoer-Wagner min cut (29) BTW, its probably a good moment to remove nx now
# Processing circuit qpeinexact with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (15) and Rustworkx Stoer-Wagner min cut (15) BTW, its probably a good moment to remove nx now
# Processing circuit qpeinexact with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vbe_ripple_carry_adder with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit vbe_ripple_carry_adder with 115 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit vbe_ripple_carry_adder with 103 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit vbe_ripple_carry_adder with 88 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit vbe_ripple_carry_adder with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit vbe_ripple_carry_adder with 61 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit vbe_ripple_carry_adder with 46 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit vbe_ripple_carry_adder with 31 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit vbe_ripple_carry_adder with 19 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit vbe_ripple_carry_adder with 4 qubits.
# Info: Agreement between NetworkX edge connectivity (2) and Rustworkx Stoer-Wagner min cut (2) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_real_amp with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_real_amp with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_real_amp with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_real_amp with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_real_amp with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_real_amp with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_real_amp with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_real_amp with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_real_amp with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_real_amp with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_su2 with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_su2 with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_su2 with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_su2 with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_su2 with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_su2 with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_su2 with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_su2 with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_su2 with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_su2 with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_two_local with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (129) and Rustworkx Stoer-Wagner min cut (129) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_two_local with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (115) and Rustworkx Stoer-Wagner min cut (115) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_two_local with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (101) and Rustworkx Stoer-Wagner min cut (101) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_two_local with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (86) and Rustworkx Stoer-Wagner min cut (86) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_two_local with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (72) and Rustworkx Stoer-Wagner min cut (72) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_two_local with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (58) and Rustworkx Stoer-Wagner min cut (58) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_two_local with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (44) and Rustworkx Stoer-Wagner min cut (44) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_two_local with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (29) and Rustworkx Stoer-Wagner min cut (29) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_two_local with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (15) and Rustworkx Stoer-Wagner min cut (15) BTW, its probably a good moment to remove nx now
# Processing circuit vqe_two_local with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit wstate with 130 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit wstate with 116 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit wstate with 102 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit wstate with 87 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit wstate with 73 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit wstate with 59 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit wstate with 45 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit wstate with 30 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit wstate with 16 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
# Processing circuit wstate with 2 qubits.
# Info: Agreement between NetworkX edge connectivity (1) and Rustworkx Stoer-Wagner min cut (1) BTW, its probably a good moment to remove nx now
#                                   num_gates  depth  size  num_1q_gates  \
# name                  num_qubits
# bmw_quark_cardinality 2                  91     50    91            85
#                       16               1043    194  1043           953
#                       30               1995    320  1995          1821
#                       45               3015    455  3015          2751
#                       59               3967    581  3967          3619
# ...                                     ...    ...   ...           ...
# wstate                73               1297    657  1297          1153
#                       87               1549    783  1549          1377
#                       102              1819    918  1819          1617
#                       116              2071   1044  2071          1841
#                       130              2323   1170  2323          2065
#
#                                   num_2q_gates  pct_2q_gates    ig_aspl  \
# name                  num_qubits
# bmw_quark_cardinality 2                      6      0.065934   1.000000
#                       16                    90      0.086290   5.666667
#                       30                   174      0.087218  10.333333
#                       45                   264      0.087562  15.333333
#                       59                   348      0.087724  20.000000
# ...                                        ...           ...        ...
# wstate                73                   144      0.111025  24.666667
#                       87                   172      0.111039  29.333333
#                       102                  202      0.111050  34.333333
#                       116                  230      0.111057  39.000000
#                       130                  258      0.111063  43.666667
#
#                                   ig_std_adj_mat  ig_diameter  \
# name                  num_qubits
# bmw_quark_cardinality 2                 0.000000            1
#                       16                1.984313           15
#                       30                1.496663           29
#                       45                1.236482           44
#                       59                1.085805           58
# ...                                          ...          ...
# wstate                73                0.326476           72
#                       87                0.299733           86
#                       102               0.277297          101
#                       116               0.260339          115
#                       130               0.246154          129
#
#                                   ig_max_betweenness  ...  ig_min_pagerank  \
# name                  num_qubits                      ...
# bmw_quark_cardinality 2                     0.000000  ...         0.500000
#                       16                    0.533333  ...         0.040151
#                       30                    0.517241  ...         0.021413
#                       45                    0.511628  ...         0.014276
#                       59                    0.508772  ...         0.010887
# ...                                              ...  ...              ...
# wstate                73                    0.507042  ...         0.008801
#                       87                    0.505882  ...         0.007385
#                       102                   0.504950  ...         0.006300
#                       116                   0.504348  ...         0.005540
#                       130                   0.503876  ...         0.004939
#
#                                   ig_std_pagerank  ig_normalized_hhi_pagerank  \
# name                  num_qubits
# bmw_quark_cardinality 2                  0.000000                    0.000000
#                       16                 0.008962                    0.001371
#                       30                 0.003489                    0.000378
#                       45                 0.001899                    0.000166
#                       59                 0.001265                    0.000096
# ...                                           ...                         ...
# wstate                73                 0.000919                    0.000062
#                       87                 0.000706                    0.000044
#                       102                0.000556                    0.000032
#                       116                0.000458                    0.000025
#                       130                0.000387                    0.000020
#
#                                   gdg_critical_path_length  \
# name                  num_qubits
# bmw_quark_cardinality 2                                 49
#                       16                               193
#                       30                               319
#                       45                               454
#                       59                               580
# ...                                                    ...
# wstate                73                               656
#                       87                               782
#                       102                              917
#                       116                             1043
#                       130                             1169
#
#                                   gdg_num_critical_paths  \
# name                  num_qubits
# bmw_quark_cardinality 2                               16
#                       16                             472
#                       30                            1732
#                       45                            3952
#                       59                            6836
# ...                                                  ...
# wstate                73                               1
#                       87                               1
#                       102                              1
#                       116                              1
#                       130                              1
#
#                                   gdg_mean_path_length  gdg_std_path_length  \
# name                  num_qubits
# bmw_quark_cardinality 2                      47.500000             0.866025
#                       16                    173.944973            12.292369
#                       30                    292.203491            13.702233
#                       45                    419.379653            14.343227
#                       59                    538.218260            14.705643
# ...                                                ...                  ...
# wstate                73                    252.034259           149.602779
#                       87                    298.747573           177.860579
#                       102                   348.783713           208.118496
#                       116                   395.475873           236.348123
#                       130                   442.162656           264.570405
#
#                                   gdg_percentage_gates_in_critical_path  \
# name                  num_qubits
# bmw_quark_cardinality 2                                        0.549451
#                       16                                       0.186002
#                       30                                       0.160401
#                       45                                       0.150912
#                       59                                       0.146458
# ...                                                                 ...
# wstate                73                                       0.506554
#                       87                                       0.505487
#                       102                                      0.504673
#                       116                                      0.504104
#                       130                                      0.503659
#
#                                   density_score  idling_score
# name                  num_qubits
# bmw_quark_cardinality 2                0.940000      0.030000
#                       16               0.322680      0.634987
#                       30               0.199246      0.774062
#                       45               0.141059      0.839853
#                       59               0.110808      0.874121
# ...                                         ...           ...
# wstate                73               0.016574      0.969955
#                       87               0.013930      0.974736
#                       102              0.011896      0.978416
#                       116              0.010470      0.981000
#                       130              0.009349      0.983031
#
# [230 rows x 37 columns]

# %% [markdown]
# # Adding A New Circuit

# %%
circuits = ds.instantiate_circuits(circuit_names=["qft"], n_vals=10)


def to_feature_dict(c: crc.Circuit) -> Dict[str, any]:
    return {
        "name": c.name,
        "num_qubits": c.num_qubits,
        "num_gates": c.num_gates,
        "depth": c.depth,
        "num_1q_gates": c.num_1q_gates,
    }


data = ds.collect_circuit_data(circuits, dict_fn=to_feature_dict)
dataset = ds.create_append_or_update_dataset(data, save_csv=True)
print(dataset)

# %% [markdown]
# # Adding A New Feature

# %% [markdown]
# # Updating Some Values For Some Circuits
